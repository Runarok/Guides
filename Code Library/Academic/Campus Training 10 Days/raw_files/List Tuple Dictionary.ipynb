# %% [markdown]
# # 🐍 Python Basics – List, Tuple, Dictionary (Beginner Level)
# This notebook includes 10 simple programs using Python's basic data structures. Each program is in its own code cell and can be run independently.

# %% [markdown]
# ## 1️⃣ Program 1: Find the Maximum Element in a List

# %%
numbers = [5, 12, 7, 3, 9]
max_value = numbers[0]
for num in numbers:
    if num > max_value:
        max_value = num
print("Maximum number:", max_value)
# Out:
# Maximum number: 12

# %% [markdown]
# ## 2️⃣ Program 2: Print First 3 Elements and Reverse the List

# %%
data = [10, 20, 30, 40, 50]
print("First 3 elements:", data[:3])
print("Reversed list:", data[::-1])

# %% [markdown]
# ## 3️⃣ Program 3: Remove Duplicates from a List

# %%
data = [10, 20, 30, 40, 50]
print("First 3 elements:", data[:3])
print("Reversed list:", data[::-1])

# %% [markdown]
# ## 4️⃣ Program 4: List Comprehension to Square Numbers

# %%
numbers = [1, 2, 3, 4, 5]
squares = [n ** 2 for n in numbers]
print("Squares:", squares)

# %% [markdown]
# ## 5️⃣ Program 5: Use Tuple as Dictionary Key

# %%
coordinates = {}
coordinates[(0, 0)] = "Origin"
coordinates[(1, 2)] = "Point A"
coordinates[(2, 3)] = "Point B"
print("Coordinates Dictionary:", coordinates)

# %% [markdown]
# ## 6️⃣ Program 6: Pack and Unpack a Tuple

# %%
student = ("Alice", 21, "ECE")
name, age, department = student
print("Name:", name)
print("Age:", age)
print("Department:", department)

# %% [markdown]
# ## 7️⃣ Program 7: Count Frequency of Words

# %%
sentence = "apple orange apple banana orange apple"
words = sentence.split()
frequency = {}
for word in words:
    if word in frequency:
        frequency[word] += 1
    else:
        frequency[word] = 1
print("Word Frequency:", frequency)

# %% [markdown]
# ## 8️⃣ Program 8: Invert a Dictionary

# %%
original = {'a': 1, 'b': 2, 'c': 3}
inverted = {}
for key, value in original.items():
    inverted[value] = key
print("Inverted Dictionary:", inverted)

# %% [markdown]
# ## 9️⃣ Program 9: Loop Through Dictionary
# Print all key-value pairs from a dictionary of student scores.

# %%
student_scores = {
    "Alice": 85,
    "Bob": 90,
    "Charlie": 78
}
for name, score in student_scores.items():
    print(name, "scored", score)

# %% [markdown]
# ## 🔟 Program 10: Store Student Records as Tuples in a List, Then Use Dictionary for Lookup

# %%
# List of student records (ID, Name, Department)
students = [
    (101, "Alice", "ECE"),
    (102, "Bob", "CSE"),
    (103, "Charlie", "ECE")
]

# Create dictionary for lookup by ID
student_dict = {}
for sid, name, dept in students:
    student_dict[sid] = (name, dept)

# Lookup a student by ID
search_id = 102
if search_id in student_dict:
    print("Details for ID", search_id, ":", student_dict[search_id])
else:
    print("Student not found.")
